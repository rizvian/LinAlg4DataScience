# %%
import numpy as np
import plotly.express as px

# %%
xy = np.array([3,4])
xyplot = xy
for lp in range(100):
    R = np.array([[np.cos(lp+1/10), np.sin(lp+1/10)],[-np.sin(lp+1/10),np.cos(lp+1/10)]])
    xyplot = np.vstack((xyplot, R@xy))

x = xyplot[:,0]
y = xyplot[:,1]
px.scatter(x = x, y = y)

# %%
xy = np.array([3,4])
xyplot = xy
xyploo = xy
for lp in np.linspace(0,1,30):
    # print(lp)
    #R = np.array([[np.cos(lp), np.cos(lp)],[np.cos(lp),np.sin(lp)]])
    Ro = np.array([[np.cos(lp),np.cos(lp)],[np.cos(lp),-np.cos(lp)]])
    # xyplot = np.vstack((xyplot, R@xy))
    print(np.sin(lp), np.cos(lp))
    xyploo = np.vstack((xyploo,Ro@xy))

x = xyploo[:,0]
y = xyploo[:,1]
px.scatter(x = x, y = y)
# Out:
# 0.0 1.0
# 0.03447592534511015 0.9994055285876692
# 0.06891086078615766 0.9976228211431968
# 0.1032638651537322 0.9946539972038074
# 0.1374940946897854 0.9905025865314216
# 0.17156085160852383 0.9851735249159703
# 0.20542363248374942 0.9786731483070236
# 0.23904217640511752 0.9710091852807082
# 0.2723765128460573 0.9621907478508727
# 0.30538700918644235 0.952228320635424
# 0.3380344178335103 0.9411337483907162
# 0.37027992288500633 0.9289202219288122
# 0.402085186279072 0.9156022624343629
# 0.43341239337600845 0.9011957041997483
# 0.46422429791772096 0.8857176757990094
# 0.4944842663113907 0.8691865797229532
# 0.5241563211847213 0.8516220704996432
# 0.5532051841609783 0.8330450313262892
# 0.5815963178029615 0.8134775492403196
# 0.6092959666760431 0.7929428888591574
# 0.6362711974814501 0.7714654647199196
# 0.6624899382120725 0.7490708122519287
# 0.6879210162842471 0.7257855574165475
# 0.7125341956001766 0.7016373850504327
# 0.7363002124969211 0.676655005949848
# 0.7591908105392207 0.6508681227351676
# 0.7811787741147804 0.6243073945361602
# 0.8022379607920784 0.5970044005400359
# 0.8223433324022215 0.5689916024455981
# 0.8414709848078965 0.5403023058681398
