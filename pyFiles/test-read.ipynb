# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.array([4,5,1])
b = np.array([-4,0,-4])
c = np.array([1,3,2])
print ((1*a)+(2*b)+(-3*c))
# Out:
# [ -7  -4 -13]
# [-8  0 -8]

# %%
a = np.array([5,3])
b = np.array([7,0])
lc = np.dot(b,a)/np.dot(b,b)
c = b*lc
d = a - c

print("a=",a,"b=",b,"c=",c, "d=",d, "lc=",lc)

plt.arrow(0,0,a[0],a[1],head_width=0.5, length_includes_head=True)
plt.arrow(0,0,b[0],b[1],head_width=0.5, length_includes_head=True)
plt.arrow(a[0],a[1], c[0]-a[0], c[1]-a[1], head_width=0.5, length_includes_head=True)
plt.arrow(0,0,d[0],d[1],head_width=0.5, length_includes_head=True)
plt.axis([-10,10,-10,10])
plt.grid()
# Out:
# a= [5 3] b= [7 0] c= [5. 0.] d= [0. 3.] lc= 0.7142857142857143

# %%
v1 = np.array([1,2,3])
v2 = np.array([2,3,4])
v3 = np.array([3,4,5])

v = [v1,v2,v3]
s = [1,-2,3,4,5]

ans = np.zeros(3)
for lps, lpv in zip(s,v):
    print(ans, lps, lpv)
    ans += lps*lpv

ans
# Out:
# [0. 0. 0.] 1 [1 2 3]
# [1. 2. 3.] -2 [2 3 4]
# [-3. -4. -5.] 3 [3 4 5]
# array([ 6.,  8., 10.])

# %%
import random as rnd
plt.plot()
plt.axis([0,10,0,10])
for lp in range(1,1000):
    x = rnd.uniform(0,10)
    y = rnd.uniform(0,10)
    dx = rnd.uniform(-.5,.5)
    dy = rnd.uniform(-.5,.5)
    c = rnd.choice(['red','blue','green','cyan','magenta','yellow','black']) 
    plt.arrow(x,y,dx,dy,head_width=.1, length_includes_head=True, color=c )

# %%
print(rnd.uniform(-10,10),)
# Out:
# 5.6308857341740115
